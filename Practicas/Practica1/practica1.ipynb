# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from importlib.metadata import version
print(f"Versión de Pandas: {version('pandas')}")
print(f"Versión de Matplotlib: {version('matplotlib')}")
print(f"Versión de Seaborn: {version('seaborn')}")
# Out:
# Versión de Pandas: 2.3.2
# Versión de Matplotlib: 3.8.1
# Versión de Seaborn: 0.13.2

# %%
datos_inmuebles = pd.read_excel('Venta_Inmuebles.xlsx')
diccionario_ventas = pd.read_excel('diccionario_Venta_Inmuebles.xlsx')

# %%
data1 = datos_inmuebles.copy()
data2 = diccionario_ventas.copy()

# %%
data1.head()
# Out:
#            Id            Fecha    Precio  Cuartos  Baños  AreaHabitable  \
# 0  7129300520  20141013T000000  221900.0        3   1.00           1180
# 1  6414100192  20141209T000000  538000.0        3   2.25           2570
# 2  5631500400  20150225T000000  180000.0        2   1.00            770
# 3  2487200875  20141209T000000  604000.0        4   3.00           1960
# 4  1954400510  20150218T000000  510000.0        3   2.00           1680
#
#    AreaLote  Pisos FrenteMar  Vista  ...  Calificación  AreaSuperior  \
# 0      5650    1.0        NO      0  ...           7.0          1180
# 1      7242    2.0        NO      0  ...           7.0          2170
# 2     10000    1.0        NO      0  ...           6.0           770
# 3      5000    1.0        NO      0  ...           7.0          1050
# 4      8080    1.0        NO      0  ...           8.0          1680
#
#    AreaBase  Años  Renovación  CodigoPostal   Latitud  Longitud  \
# ...

# %%
data1.shape
# Out:
# (21613, 21)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               21613 non-null  int64
#  1   Fecha            21613 non-null  object
#  2   Precio           21613 non-null  float64
#  3   Cuartos          21613 non-null  int64
#  4   Baños            21613 non-null  float64
#  5   AreaHabitable    21613 non-null  int64
#  6   AreaLote         21613 non-null  int64
#  7   Pisos            21613 non-null  float64
#  8   FrenteMar        21613 non-null  object
#  9   Vista            21613 non-null  int64
#  10  Condición        21613 non-null  int64
#  11  Calificación     21607 non-null  float64
#  12  AreaSuperior     21613 non-null  int64
#  13  AreaBase         21613 non-null  int64
#  14  Años             21613 non-null  int64
#  15  Renovación       21613 non-null  int64
#  16  CodigoPostal     21613 non-null  int64
# ...

# %%
data1.describe()
# Out:
#                  Id        Precio       Cuartos         Baños  AreaHabitable  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000   21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757    2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163     918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000     290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000    1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000    1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000    2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000   13540.000000
#
#            AreaLote         Pisos         Vista     Condición  Calificación  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21607.000000
# mean   1.510697e+04      1.494309      0.247397      3.409430      7.656500
# ...

# %%
data2.describe()
# Out:
#        Variable  Tipo                                        Descripción
# count        21     21                                                 21
# unique       21      4                                                 21
# top          ID  int64  Identificador único de la transacción o propie...
# freq          1     14                                                  1

# %%
data1.iloc[99]
# Out:
# Id                      7338200240
# Fecha              20140516T000000
# Precio                    437500.0
# Cuartos                          3
# Baños                          2.5
# AreaHabitable                 2320
# AreaLote                     36847
# Pisos                          2.0
# FrenteMar                       NO
# Vista                            2
# Condición                        3
# Calificación                   9.0
# AreaSuperior                  2320
# AreaBase                         0
# Años                          1992
# Renovación                       0
# CodigoPostal                 98045
# Latitud                   474838.0
# Longitud                 -121714.0
# AreaHabitable15               2550
# AreaLote15                   35065
# Name: 99, dtype: object

# %%
data1.iloc[99:105]
# Out:
#              Id            Fecha     Precio  Cuartos  Baños  AreaHabitable  \
# 99   7338200240  20140516T000000   437500.0        3   2.50           2320
# 100  1952200240  20140611T000000   850830.0        3   2.50           2070
# 101  5200100125  20141027T000000   555000.0        3   2.00           1980
# 102  7214720075  20141212T000000   699950.0        3   2.25           2190
# 103  2450000295  20141007T000000  1090000.0        3   2.50           2920
# 104  6197800045  20140924T000000   290000.0        3   1.00           1210
#
#      AreaLote  Pisos FrenteMar  Vista  ...  Calificación  AreaSuperior  \
# 99      36847    2.0        NO      2  ...           9.0          2320
# 100     13241    1.5        NO      0  ...           9.0          1270
# 101      3478    1.5        NO      0  ...           7.0          1440
# 102    107593    2.0        NO      0  ...           8.0          2190
# 103      8113    2.0        NO      0  ...           8.0          2920
# ...

# %% [markdown]
# # Ejercicios
# 1) selección filas de posicion 10 a 19
# 2) seleccion de las ultimas 5 filas usando indices negativos
# 3) Selecciona los registros en posiciones pares entre los indices 10 y 20

# %%
#1)

data1.iloc[10:20]
# Out:
#             Id            Fecha    Precio  Cuartos  Baños  AreaHabitable  \
# 10  1736800520  20150403T000000  662500.0        3   2.50           3560
# 11  9212900260  20140527T000000  468000.0        2   1.00           1160
# 12   114101516  20140528T000000  310000.0        3   1.00           1430
# 13  6054650070  20141007T000000  400000.0        3   1.75           1370
# 14  1175000570  20150312T000000  530000.0        5   2.00           1810
# 15  9297300055  20150124T000000  650000.0        4   3.00           2950
# 16  1875500060  20140731T000000  395000.0        3   2.00           1890
# 17  6865200140  20140529T000000  485000.0        4   1.00           1600
# 18    16000397  20141205T000000  189000.0        2   1.00           1200
# 19  7983200060  20150424T000000  230000.0        3   1.00           1250
#
#     AreaLote  Pisos FrenteMar  Vista  ...  Calificación  AreaSuperior  \
# 10      9796    1.0        NO      0  ...           8.0          1860
# ...

# %%
#2
data1.iloc[-5:]
# Out:
#                Id            Fecha    Precio  Cuartos  Baños  AreaHabitable  \
# 21608   263000018  20140521T000000  360000.0        3   2.50           1530
# 21609  6600060120  20150223T000000  400000.0        4   2.50           2310
# 21610  1523300141  20140623T000000  402101.0        2   0.75           1020
# 21611   291310100  20150116T000000  400000.0        3   2.50           1600
# 21612  1523300157  20141015T000000  325000.0        2   0.75           1020
#
#        AreaLote  Pisos FrenteMar  Vista  ...  Calificación  AreaSuperior  \
# 21608      1131    3.0        NO      0  ...           8.0          1530
# 21609      5813    2.0        NO      0  ...           8.0          2310
# 21610      1350    2.0        NO      0  ...           7.0          1020
# 21611      2388    2.0        NO      0  ...           8.0          1600
# 21612      1076    2.0        NO      0  ...           7.0          1020
#
# ...

# %%
#3
data1.iloc[10:21:2]
# Out:
#             Id            Fecha    Precio  Cuartos  Baños  AreaHabitable  \
# 10  1736800520  20150403T000000  662500.0        3   2.50           3560
# 12   114101516  20140528T000000  310000.0        3   1.00           1430
# 14  1175000570  20150312T000000  530000.0        5   2.00           1810
# 16  1875500060  20140731T000000  395000.0        3   2.00           1890
# 18    16000397  20141205T000000  189000.0        2   1.00           1200
# 20  6300500875  20140514T000000  385000.0        4   1.75           1620
#
#     AreaLote  Pisos FrenteMar  Vista  ...  Calificación  AreaSuperior  \
# 10      9796    1.0        NO      0  ...           8.0          1860
# 12     19901    1.5        NO      0  ...           7.0          1430
# 14      4850    1.5        NO      0  ...           7.0          1810
# 16     14040    2.0        NO      0  ...           7.0          1890
# 18      9850    1.0        no      0  ...           7.0          1200
# ...

# %%
data1.loc[:,'Cuartos']
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: Cuartos, Length: 21613, dtype: int64

# %%
data1.iloc[:,3]
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: Cuartos, Length: 21613, dtype: int64

# %%
data1.loc[:,['Precio', 'Cuartos']]
# Out:
#          Precio  Cuartos
# 0      221900.0        3
# 1      538000.0        3
# 2      180000.0        2
# 3      604000.0        4
# 4      510000.0        3
# ...         ...      ...
# 21608  360000.0        3
# 21609  400000.0        4
# 21610  402101.0        2
# 21611  400000.0        3
# 21612  325000.0        2
#
# [21613 rows x 2 columns]

# %% [markdown]
# # Ejercicios
# 1) Selecciona las columnas de la posicion 2 a 4
# 2) tare las siguientes columnas en este mismo orden(id, yr_built, bedrooms, bathrooms, price)
# 3) Selecciona de la segunda a la quinta fula y las columnas (id, sqrt_living)

# %%
#1)
data1.iloc[:,1:4]
# Out:
#                  Fecha    Precio  Cuartos
# 0      20141013T000000  221900.0        3
# 1      20141209T000000  538000.0        3
# 2      20150225T000000  180000.0        2
# 3      20141209T000000  604000.0        4
# 4      20150218T000000  510000.0        3
# ...                ...       ...      ...
# 21608  20140521T000000  360000.0        3
# 21609  20150223T000000  400000.0        4
# 21610  20140623T000000  402101.0        2
# 21611  20150116T000000  400000.0        3
# 21612  20141015T000000  325000.0        2
#
# [21613 rows x 3 columns]

# %%
#2
data1.loc[:, ['Id', 'Fecha', 'Cuartos', 'Baños', 'Precio']]
# Out:
#                Id            Fecha  Cuartos  Baños    Precio
# 0      7129300520  20141013T000000        3   1.00  221900.0
# 1      6414100192  20141209T000000        3   2.25  538000.0
# 2      5631500400  20150225T000000        2   1.00  180000.0
# 3      2487200875  20141209T000000        4   3.00  604000.0
# 4      1954400510  20150218T000000        3   2.00  510000.0
# ...           ...              ...      ...    ...       ...
# 21608   263000018  20140521T000000        3   2.50  360000.0
# 21609  6600060120  20150223T000000        4   2.50  400000.0
# 21610  1523300141  20140623T000000        2   0.75  402101.0
# 21611   291310100  20150116T000000        3   2.50  400000.0
# 21612  1523300157  20141015T000000        2   0.75  325000.0
#
# [21613 rows x 5 columns]

# %%
#3
data1.loc[1:4, ['Id', 'AreaHabitable']]
# Out:
#            Id  AreaHabitable
# 1  6414100192           2570
# 2  5631500400            770
# 3  2487200875           1960
# 4  1954400510           1680

# %%
data1[data1.loc[:, 'Baños'] > 1]
# Out:
#                Id            Fecha     Precio  Cuartos  Baños  AreaHabitable  \
# 1      6414100192  20141209T000000   538000.0        3   2.25           2570
# 3      2487200875  20141209T000000   604000.0        4   3.00           1960
# 4      1954400510  20150218T000000   510000.0        3   2.00           1680
# 5      7237550310  20140512T000000  1230000.0        4   4.50           5420
# 6      1321400060  20140627T000000   257500.0        3   2.25           1715
# ...           ...              ...        ...      ...    ...            ...
# 21606  7936000429  20150326T000000  1010000.0        4   3.50           3510
# 21607  2997800021  20150219T000000   475000.0        3   2.50           1310
# 21608   263000018  20140521T000000   360000.0        3   2.50           1530
# 21609  6600060120  20150223T000000   400000.0        4   2.50           2310
# 21611   291310100  20150116T000000   400000.0        3   2.50           1600
#
# ...

# %% [markdown]
# # Ejercicios
# 1) Selecciona las casas con un precio mayor a 1 millon
# 2) Trae las casas construidas en este siglo
# 3) Selecciona los registros que fueron remodelados

# %%
#1
data1[data1['Precio'] > 1000000]
# Out:
#                Id            Fecha     Precio  Cuartos  Baños  AreaHabitable  \
# 5      7237550310  20140512T000000  1230000.0        4   4.50           5420
# 21     2524049179  20140826T000000  2000000.0        3   2.75           3050
# 49      822039084  20150311T000000  1350000.0        3   2.50           2753
# 69     1802000060  20140612T000000  1330000.0        5   2.25           3200
# 70     1525059190  20140912T000000  1040000.0        5   3.25           4770
# ...           ...              ...        ...      ...    ...            ...
# 21590  7430200100  20140514T000000  1220000.0        4   3.50           4910
# 21593  8672200110  20150317T000000  1090000.0        5   3.75           4170
# 21597   191100405  20150421T000000  1580000.0        4   3.25           3410
# 21600   249000205  20141015T000000  1540000.0        5   3.75           4470
# 21606  7936000429  20150326T000000  1010000.0        4   3.50           3510
#
# ...

# %%
#2
data1[data1['Fecha'] > "20000000T000000"]
# Out:
#                Id            Fecha    Precio  Cuartos  Baños  AreaHabitable  \
# 0      7129300520  20141013T000000  221900.0        3   1.00           1180
# 1      6414100192  20141209T000000  538000.0        3   2.25           2570
# 2      5631500400  20150225T000000  180000.0        2   1.00            770
# 3      2487200875  20141209T000000  604000.0        4   3.00           1960
# 4      1954400510  20150218T000000  510000.0        3   2.00           1680
# ...           ...              ...       ...      ...    ...            ...
# 21608   263000018  20140521T000000  360000.0        3   2.50           1530
# 21609  6600060120  20150223T000000  400000.0        4   2.50           2310
# 21610  1523300141  20140623T000000  402101.0        2   0.75           1020
# 21611   291310100  20150116T000000  400000.0        3   2.50           1600
# 21612  1523300157  20141015T000000  325000.0        2   0.75           1020
#
# ...

# %%
#3
data1[data1['Renovación'] != 0]
# Out:
#                Id            Fecha     Precio  Cuartos  Baños  AreaHabitable  \
# 1      6414100192  20141209T000000   538000.0        3   2.25           2570
# 35     9547205180  20140613T000000   696000.0        3   2.50           2300
# 95     1483300570  20140908T000000   905000.0        4   2.50           3300
# 103    2450000295  20141007T000000  1090000.0        3   2.50           2920
# 115    3626039325  20141121T000000   740500.0        3   3.50           4380
# ...           ...              ...        ...      ...    ...            ...
# 19622  7351200295  20150114T000000  1150000.0        3   1.75           1760
# 20057   126039256  20140904T000000   434900.0        3   2.00           1520
# 20444  4305600360  20150225T000000   500012.0        4   2.50           2400
# 20447  3319500628  20150212T000000   356999.0        3   1.50           1010
# 20962  1278000210  20150311T000000   110000.0        2   1.00            828
#
# ...

# %%
# Tamaño de la gráfica
plt.figure(figsize=(16,6))

# Cantidad de apariciones de cada año de construcción
plot_data = data1['Años'].value_counts()

# Valores únicos (años) y sus frecuencias
x = plot_data.index
y = plot_data.values

# Gráfico de barras
plt.bar(x,y)

# Títulos de los ejes y del gráfico
plt.xlabel("Años")
plt.ylabel("Cantidad de inmuebles")
plt.title('Distribución de Años de construcción')

# Mostrar la gráfica
plt.show()

# %%
plt.figure(figsize=(16,6))

# Variable a graficar
x = data1['Precio']

# Histograma
plt.hist(x, bins=50)

# Títulos de los ejes y de la gráfica
plt.xlabel(" Precio")
plt.ylabel("Frecuencia")
plt.title('Precio de las casas')

# Mostrar gráfica
plt.show()

# %%
plt.figure(figsize=(10,10))

x = data1['Baños']
y = data1['Precio']

plt.plot(x, y, '.', color='blue')
plt.title('No. Baños vs Precio')
plt.xlabel('No. Baños')
plt.ylabel('Precio')
plt.show()

# %%
# Obtener el número de valores de cada categoría
bedrooms_count = data1['Cuartos'].value_counts()#.head(5)

# Función para ilustrar en forma de pie
plt.pie(bedrooms_count, labels=bedrooms_count.index, autopct='%1.1f%%')

# Título
plt.title('Distribución por Número de Habitaciones')

# Mostrar
plt.show()

# %%
sns.regplot(x='AreaHabitable', y='Precio', data=data1)
# Out:
# <Axes: xlabel='AreaHabitable', ylabel='Precio'>

# %% [markdown]
# # Construir un gráfico que relacione los pisos con el número de habitaciones

# %%
sns.regplot(x='Pisos', y='Cuartos', data=data1)
# Out:
# <Axes: xlabel='Pisos', ylabel='Cuartos'>

# %%
plt.figure(figsize=(10,10))

x = data1['FrenteMar']
y = data1['Precio']

plt.plot(x, y, '.', color='blue')
plt.title('No. pisos vs No. cuartos')
plt.xlabel('No. pisos')
plt.ylabel('No. baños')
plt.show()

# %%
data1['FrenteMar'].value_counts()
# Out:
# FrenteMar
# NO    21446
# SI      163
# no        4
# Name: count, dtype: int64

# %%
pd.get_dummies(data1['FrenteMar'])
# Out:
#          NO     SI     no
# 0      True  False  False
# 1      True  False  False
# 2      True  False  False
# 3      True  False  False
# 4      True  False  False
# ...     ...    ...    ...
# 21608  True  False  False
# 21609  True  False  False
# 21610  True  False  False
# 21611  True  False  False
# 21612  True  False  False
#
# [21613 rows x 3 columns]

# %%
data1[data1['Cuartos'] >= 10].value_counts()
# Out:
# Id          Fecha            Precio     Cuartos  Baños  AreaHabitable  AreaLote  Pisos  FrenteMar  Vista  Condición  Calificación  AreaSuperior  AreaBase  Años  Renovación  CodigoPostal  Latitud   Longitud    AreaHabitable15  AreaLote15
# 627300145   20140814T000000  1150000.0  10       5.25   4590           10920     1.0    NO         2      3          9.0           2500          2090      2008  0           98004         475861.0  -122113.00  2730             10400         1
# 1773100755  20140821T000000  520000.0   11       3.00   3000           4960      2.0    NO         0      3          7.0           2400          600       1918  1999        98106         47556.0   -122363.00  1420             4960          1
# 2402100895  20140625T000000  640000.0   33       1.75   1620           6000      1.0    NO         0      5          7.0           1040          580       1947  0           98103         476878.0  -122331.00  1330             4700          1
# ...

# %%
data1['AreaHabitable'].max()
# Out:
# 13540

# %%
data1[data1['Id'] == 2402100895]
# Out:
#                Id            Fecha    Precio  Cuartos  Baños  AreaHabitable  \
# 15870  2402100895  20140625T000000  640000.0       33   1.75           1620
#
#        AreaLote  Pisos FrenteMar  Vista  ...  Calificación  AreaSuperior  \
# 15870      6000    1.0        NO      0  ...           7.0          1040
#
#        AreaBase  Años  Renovación  CodigoPostal   Latitud  Longitud  \
# 15870       580  1947           0         98103  476878.0 -122331.0
#
#        AreaHabitable15  AreaLote15
# 15870             1330        4700
#
# [1 rows x 21 columns]

# %%
sns.regplot(x='Latitud', y='CodigoPostal', data=data1)
# Out:
# <Axes: xlabel='Latitud', ylabel='CodigoPostal'>

# %%
total_duplicados = data1.duplicated().sum()
total_duplicados
# Out:
# 0

# %%
#Matriz de correlacion
import numpy as np
df_numeric = data1.select_dtypes(include=[np.number])
df_numeric.corr()['Precio'].sort_values()
# Out:
# CodigoPostal      -0.053168
# Id                -0.016797
# Latitud            0.006906
# Longitud           0.012644
# Condición          0.036392
# Años               0.053982
# AreaLote15         0.082456
# AreaLote           0.089655
# Renovación         0.126442
# Pisos              0.256786
# Vista              0.275119
# Cuartos            0.308338
# AreaBase           0.323837
# Baños              0.525134
# AreaHabitable15    0.585374
# AreaSuperior       0.605566
# Calificación       0.667405
# AreaHabitable      0.702044
# Precio             1.000000
# Name: Precio, dtype: float64

# %%
sns.boxplot(x='Cuartos', y='Pisos', data = data1)
# Out:
# <Axes: xlabel='Cuartos', ylabel='Pisos'>
